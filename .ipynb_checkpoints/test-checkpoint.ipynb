# %%
import numpy as np
test = np.load('EQTransformer/ModelsAndSampleData/test.npy')

selectDataSize=8000
csv_file = "../../MLData/metadata_11_13_19.csv"
file_name = "../../MLData/waveforms_11_13_19.hdf5"

# %%
len(test)
# Out:
# 126566

# %%
import pandas as pd
df = pd.read_csv(csv_file)
# Out:
# /home/tian_feng/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7,11,13,14,15,18,19,20,21,22,24,25,26,30,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test[0] in list(df.trace_name)
# Out:
# True

# %%
from EQTransformer.core.trainer import trainer
trainer(input_hdf5='EQTransformer/ModelsAndSampleData/100samples.hdf5',
        input_csv='EQTransformer/ModelsAndSampleData/100samples.csv',
        output_name='test_trainer',                
        cnn_blocks=2,
        lstm_blocks=1,
        padding='same',
        activation='relu',
        drop_rate=0.2,
        label_type='gaussian',
        add_event_r=0.6,
        add_gap_r=0.2,
        shift_event_r=0.9,
        add_noise_r=0.5, 
        mode='generator',
        train_valid_test_split=[0.60, 0.20, 0.20],
        batch_size=20,
        epochs=10, 
        patience=2,
        gpuid=None,
        gpu_limit=None)
# Out:
# Using TensorFlow backend.
# 2021-10-22 22:39:05.350845: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-10-22 22:39:05.361668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.362188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.683
# pciBusID: 0000:01:00.0
# 2021-10-22 22:39:05.362346: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-10-22 22:39:05.363576: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-10-22 22:39:05.364326: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-10-22 22:39:05.364526: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-10-22 22:39:05.365483: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-10-22 22:39:05.366213: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-10-22 22:39:05.368557: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-22 22:39:05.368713: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.369218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.369724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-10-22 22:39:05.370314: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2021-10-22 22:39:05.377375: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 4007905000 Hz
# 2021-10-22 22:39:05.377619: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e45da1c600 executing computations on platform Host. Devices:
# 2021-10-22 22:39:05.377634: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2021-10-22 22:39:05.433267: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.433599: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e45da4a5b0 executing computations on platform CUDA. Devices:
# 2021-10-22 22:39:05.433611: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): NVIDIA GeForce GTX 1070, Compute Capability 6.1
# 2021-10-22 22:39:05.433755: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.434010: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.683
# pciBusID: 0000:01:00.0
# 2021-10-22 22:39:05.434046: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-10-22 22:39:05.434058: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-10-22 22:39:05.434069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-10-22 22:39:05.434080: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-10-22 22:39:05.434091: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-10-22 22:39:05.434102: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-10-22 22:39:05.434113: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-10-22 22:39:05.434159: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.434431: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.434667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-10-22 22:39:05.434694: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-10-22 22:39:05.435507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-22 22:39:05.435514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-10-22 22:39:05.435518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-10-22 22:39:05.435591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.435866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-22 22:39:05.436118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7515 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 6000, 3)      0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 8)      272         input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 3000, 8)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 3000, 16)     1168        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 1500, 16)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1500, 16)     1808        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 750, 16)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 750, 32)      3616        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 375, 32)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 375, 32)      5152        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 188, 32)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 188, 64)      10304       max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 94, 64)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 94, 64)       12352       max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 47, 64)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 47, 64)       256         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 47, 64)       0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 47, 64)       0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 47, 64)       12352       spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 47, 64)       256         conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 47, 64)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 47, 64)       0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 47, 64)       12352       spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 47, 64)       0           max_pooling1d_7[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 47, 64)       256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 47, 64)       0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 47, 64)       0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 47, 64)       256         conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 47, 64)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 47, 64)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 47, 64)       0           add_1[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 47, 32)       10368       add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 47, 16)       528         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 47, 16)       64          conv1d_12[0][0]
# __________________________________________________________________________________________________
# attentionD0 (SeqSelfAttention)  [(None, 47, 16), (No 1089        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 47, 16)       0           batch_normalization_5[0][0]
#                                                                  attentionD0[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 47, 16)       32          add_3[0][0]
# __________________________________________________________________________________________________
# feed_forward_1 (FeedForward)    (None, 47, 16)       4240        layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 47, 16)       0           layer_normalization_1[0][0]
#                                                                  feed_forward_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 47, 16)       32          add_4[0][0]
# __________________________________________________________________________________________________
# attentionD (SeqSelfAttention)   [(None, 47, 16), (No 1089        layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 47, 16)       0           layer_normalization_2[0][0]
#                                                                  attentionD[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 47, 16)       32          add_5[0][0]
# __________________________________________________________________________________________________
# feed_forward_2 (FeedForward)    (None, 47, 16)       4240        layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 47, 16)       0           layer_normalization_3[0][0]
#                                                                  feed_forward_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 47, 16)       32          add_6[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 47, 16)       2112        layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 47, 16)       2112        layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# attentionP (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_2[0][0]
# __________________________________________________________________________________________________
# attentionS (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_3[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_1 (UpSampling1D)  (None, 94, 16)       0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_8 (UpSampling1D)  (None, 94, 16)       0           attentionP[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_15 (UpSampling1D) (None, 94, 16)       0           attentionS[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_2 (UpSampling1D)  (None, 188, 64)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_9 (UpSampling1D)  (None, 188, 64)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_16 (UpSampling1D) (None, 188, 64)      0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_3 (UpSampling1D)  (None, 376, 64)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_10 (UpSampling1D) (None, 376, 64)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_17 (UpSampling1D) (None, 376, 64)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_4 (UpSampling1D)  (None, 752, 32)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_11 (UpSampling1D) (None, 752, 32)      0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_18 (UpSampling1D) (None, 752, 32)      0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# cropping1d_1 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_4[0][0]
# __________________________________________________________________________________________________
# cropping1d_2 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_11[0][0]
# __________________________________________________________________________________________________
# cropping1d_3 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 750, 32)      7200        cropping1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 750, 32)      7200        cropping1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 750, 32)      7200        cropping1d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_5 (UpSampling1D)  (None, 1500, 32)     0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_12 (UpSampling1D) (None, 1500, 32)     0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_19 (UpSampling1D) (None, 1500, 32)     0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_19[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_6 (UpSampling1D)  (None, 3000, 16)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_13 (UpSampling1D) (None, 3000, 16)     0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_20 (UpSampling1D) (None, 3000, 16)     0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_7 (UpSampling1D)  (None, 6000, 16)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_14 (UpSampling1D) (None, 6000, 16)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_21 (UpSampling1D) (None, 6000, 16)     0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_21[0][0]
# __________________________________________________________________________________________________
# detector (Conv1D)               (None, 6000, 1)      89          conv1d_19[0][0]
# __________________________________________________________________________________________________
# picker_P (Conv1D)               (None, 6000, 1)      89          conv1d_26[0][0]
# __________________________________________________________________________________________________
# picker_S (Conv1D)               (None, 6000, 1)      89          conv1d_33[0][0]
# ==================================================================================================
# Total params: 258,983
# Trainable params: 258,439
# Non-trainable params: 544
# __________________________________________________________________________________________________
# Started training in generator mode ...
# Epoch 1/10
# Learning rate:  0.001
# 2021-10-22 22:39:31.184913: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 0, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:31.472792: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 1, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:31.773501: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:502] layout failed: Invalid argument: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:31.975631: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:502] model_pruner failed: Invalid argument: MutableGraphView::MutableGraphView error: node 'loss/detector_loss/binary_crossentropy/weighted_loss/concat' has self cycle fanin 'loss/detector_loss/binary_crossentropy/weighted_loss/concat'.
# 2021-10-22 22:39:32.346202: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:502] remapper failed: Invalid argument: MutableGraphView::MutableGraphView error: node 'loss/detector_loss/binary_crossentropy/weighted_loss/concat' has self cycle fanin 'loss/detector_loss/binary_crossentropy/weighted_loss/concat'.
# 2021-10-22 22:39:32.411284: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:502] arithmetic_optimizer failed: Invalid argument: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:32.470904: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 0, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:32.734812: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 1, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:33.092328: W tensorflow/core/common_runtime/process_function_library_runtime.cc:675] Ignoring multi-device function optimization failure: Invalid argument: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:36.764371: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-10-22 22:39:36.948628: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 5/6 [========================>.....] - ETA: 2s - loss: 0.6072 - detector_loss: 0.6772 - picker_P_loss: 0.5621 - picker_S_loss: 0.6319 - detector_f1: 0.1324 - picker_P_f1: 4.6242e-04 - picker_S_f1: 4.3533e-05Epoch 1/10
# 2021-10-22 22:39:40.523967: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 0, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:40.541680: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 1, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:40.560619: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:502] layout failed: Invalid argument: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:40.590889: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:502] model_pruner failed: Invalid argument: MutableGraphView::MutableGraphView error: node 'loss/detector_loss/binary_crossentropy/weighted_loss/concat' has self cycle fanin 'loss/detector_loss/binary_crossentropy/weighted_loss/concat'.
# 2021-10-22 22:39:40.650611: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:502] remapper failed: Invalid argument: MutableGraphView::MutableGraphView error: node 'loss/detector_loss/binary_crossentropy/weighted_loss/concat' has self cycle fanin 'loss/detector_loss/binary_crossentropy/weighted_loss/concat'.
# 2021-10-22 22:39:40.661095: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:502] arithmetic_optimizer failed: Invalid argument: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:40.673652: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 0, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:40.688702: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 1, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2021-10-22 22:39:40.721396: W tensorflow/core/common_runtime/process_function_library_runtime.cc:675] Ignoring multi-device function optimization failure: Invalid argument: The graph couldn't be sorted in topological order.
# 6/6 [==============================] - 15s 2s/step - loss: 0.5670 - detector_loss: 0.6648 - picker_P_loss: 0.5145 - picker_S_loss: 0.5946 - detector_f1: 0.1103 - picker_P_f1: 3.8535e-04 - picker_S_f1: 3.6277e-05 - val_loss: 0.2152 - val_detector_loss: 0.5059 - val_picker_P_loss: 0.1387 - val_picker_S_loss: 0.2425 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.21522, saving model to /home/tian_feng/UCLA/gMLP_phase/gMLP_phase/test_trainer_outputs/models/test_trainer_001.h5
# Epoch 2/10
# Learning rate:  0.001
# 6/6 [==============================] - 2s 269ms/step - loss: 0.1147 - detector_loss: 0.5923 - picker_P_loss: 0.0683 - picker_S_loss: 0.1028 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0814 - val_detector_loss: 0.4809 - val_picker_P_loss: 0.0574 - val_picker_S_loss: 0.0603 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.21522 to 0.08140, saving model to /home/tian_feng/UCLA/gMLP_phase/gMLP_phase/test_trainer_outputs/models/test_trainer_002.h5
# Epoch 3/10
# Learning rate:  0.001
# 6/6 [==============================] - 1s 221ms/step - loss: 0.1168 - detector_loss: 0.5531 - picker_P_loss: 0.0879 - picker_S_loss: 0.0957 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.1009 - val_detector_loss: 0.5310 - val_picker_P_loss: 0.0704 - val_picker_S_loss: 0.0815 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 0.08140
# Epoch 4/10
# Learning rate:  0.001
# 6/6 [==============================] - 2s 279ms/step - loss: 0.0960 - detector_loss: 0.5241 - picker_P_loss: 0.0674 - picker_S_loss: 0.0754 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0649 - val_detector_loss: 0.4986 - val_picker_P_loss: 0.0432 - val_picker_S_loss: 0.0389 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00004: val_loss improved from 0.08140 to 0.06493, saving model to /home/tian_feng/UCLA/gMLP_phase/gMLP_phase/test_trainer_outputs/models/test_trainer_004.h5
# Epoch 5/10
# Learning rate:  0.001
# 6/6 [==============================] - 2s 277ms/step - loss: 0.0632 - detector_loss: 0.5049 - picker_P_loss: 0.0403 - picker_S_loss: 0.0373 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0613 - val_detector_loss: 0.5810 - val_picker_P_loss: 0.0277 - val_picker_S_loss: 0.0362 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00005: val_loss improved from 0.06493 to 0.06135, saving model to /home/tian_feng/UCLA/gMLP_phase/gMLP_phase/test_trainer_outputs/models/test_trainer_005.h5
# Epoch 6/10
# Learning rate:  0.001
# 6/6 [==============================] - 2s 270ms/step - loss: 0.0672 - detector_loss: 0.5230 - picker_P_loss: 0.0402 - picker_S_loss: 0.0430 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0602 - val_detector_loss: 0.5827 - val_picker_P_loss: 0.0289 - val_picker_S_loss: 0.0330 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00006: val_loss improved from 0.06135 to 0.06016, saving model to /home/tian_feng/UCLA/gMLP_phase/gMLP_phase/test_trainer_outputs/models/test_trainer_006.h5
# Epoch 7/10
# Learning rate:  0.001
# 6/6 [==============================] - 1s 223ms/step - loss: 0.0549 - detector_loss: 0.4495 - picker_P_loss: 0.0336 - picker_S_loss: 0.0321 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0563 - val_detector_loss: 0.5632 - val_picker_P_loss: 0.0278 - val_picker_S_loss: 0.0285 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00007: val_loss improved from 0.06016 to 0.05627, saving model to /home/tian_feng/UCLA/gMLP_phase/gMLP_phase/test_trainer_outputs/models/test_trainer_007.h5
# Epoch 8/10
# Learning rate:  0.001
# 6/6 [==============================] - 1s 221ms/step - loss: 0.0553 - detector_loss: 0.4370 - picker_P_loss: 0.0338 - picker_S_loss: 0.0338 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0566 - val_detector_loss: 0.5779 - val_picker_P_loss: 0.0274 - val_picker_S_loss: 0.0280 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 0.05627
# Epoch 9/10
# Learning rate:  0.001
# 6/6 [==============================] - 2s 321ms/step - loss: 0.0524 - detector_loss: 0.4177 - picker_P_loss: 0.0328 - picker_S_loss: 0.0311 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0552 - val_detector_loss: 0.5257 - val_picker_P_loss: 0.0268 - val_picker_S_loss: 0.0308 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00009: val_loss improved from 0.05627 to 0.05524, saving model to /home/tian_feng/UCLA/gMLP_phase/gMLP_phase/test_trainer_outputs/models/test_trainer_009.h5
# Epoch 10/10
# Learning rate:  0.001
# 6/6 [==============================] - 2s 271ms/step - loss: 0.0512 - detector_loss: 0.4068 - picker_P_loss: 0.0329 - picker_S_loss: 0.0299 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0520 - val_detector_loss: 0.4998 - val_picker_P_loss: 0.0259 - val_picker_S_loss: 0.0281 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00010: val_loss improved from 0.05524 to 0.05203, saving model to /home/tian_feng/UCLA/gMLP_phase/gMLP_phase/test_trainer_outputs/models/test_trainer_010.h5

# %%
from EQTransformer.core.tester import tester
tester(input_hdf5='EQTransformer/ModelsAndSampleData/100samples.hdf5',
       input_testset='test_trainer_outputs/test.npy',
       input_model='EQTransformer/ModelsAndSampleData/EqT_model.h5',
       output_name='test_tester',
       detection_threshold=0.20,                
       P_threshold=0.1,
       S_threshold=0.1, 
       number_of_plots=3,
       estimate_uncertainty=True, 
       number_of_sampling=2,
       input_dimention=(6000, 3),
       normalization_mode='std',
       mode='generator',
       batch_size=10,
       gpuid=None,
       gpu_limit=None)
# Out:
# Loading the model ...
